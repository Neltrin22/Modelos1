# %% [markdown]
# Proyecto desafío playground-series-s3e20

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import Image
import numpy as np
import seaborn as sns

# %%
d = pd.read_csv("train.csv")
d.head()

# %% [markdown]
# Tamaño de datos

# %%
## KEEPOUTPUT
print (d.shape)
# Out:
# (15181, 76)

# %% [markdown]
# valores faltantes en las columnas

# %%
## KEEPOUTPUT
k = d.isna().sum()
k[k!=0]
# Out:
# SulphurDioxide_SO2_column_number_density          2372
# SulphurDioxide_SO2_column_number_density_amf      2372
# SulphurDioxide_SO2_slant_column_number_density    2372
# SulphurDioxide_cloud_fraction                     2372
# SulphurDioxide_sensor_azimuth_angle               2372
#                                                   ...
# Cloud_sensor_azimuth_angle                           1
# Cloud_sensor_zenith_angle                            1
# Cloud_solar_azimuth_angle                            1
# Cloud_solar_zenith_angle                             1
# emission                                             1
# Length: 71, dtype: int64

# %% [markdown]
# inspeccionar variable objetivo

# %%
## KEEPOUTPUT
sns.displot(d['emission']);

# %% [markdown]
# descubriendo los datos

# %%
## KEEPOUTPUT
d.columns

# %%
## KEEPOUTPUT
for c in d.columns:
    print ("%20s"%c, d[c].dtype)

# %% [markdown]
# inspeccionando columnas numericas

# %%
## KEEPOUTPUT
d._get_numeric_data().describe().T

# %%
## KEEPOUTPUT
cols = ['ID_LAT_LON_YEAR_WEEK','latitude','longitude','year','emission']
#cols = np.unique(list(np.random.permutation(d._get_numeric_data().columns)[:5])+['emission'])
sns.set()
sns.pairplot(d[cols])
